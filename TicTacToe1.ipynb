# %%
import random
import sys
board={(0,0):1,
       (0,1):2,
       (0,2):3,
       (1,0):4,
       (1,1):5,
       (1,2):6,
       (2,0):7,
       (2,1):8,
       (2,2):9}


def DisplayBoard(board):
    print("+-----+-----+-----+")
    print("|    ",end="")
    print(" | ","  ","|","   ","|")
    print("|",board[(0,0)],"  | ","",board[(0,1)],"|"," ",board[(0,2)],"|")
    print("|","  "," |  ",""," |    ","|")
    print("+-----+-----+-----+")
    print("|    ",end="")
    print(" | ","  ","|","   ","|")
    print("|",board[(1,0)],"  | ","",board[(1,1)],"|"," ",board[(1,2)],"|")
    print("|","  "," |  ",""," |    ","|")
    print("+-----+-----+-----+")
    
    print("|    ",end="")
    print(" | ","  ","|","   ","|")
    print("|",board[(2,0)],"  | ","",board[(2,1)],"|"," ",board[(2,2)],"|")
    print("|","  "," |  ",""," |    ","|")
    print("+-----+-----+-----+")
    




def EnterUserMove(val):
    if val==1 :
        if board[(0,0)]!="X" and board[(0,0)]!="O":
            board[(0,0)]="O"
            print (board[(0,0)])
            DisplayBoard(board)
            VictoryFor(board, "O")
            DrawComputerMove()
        else:
            print("In valid ! Enter Again : ")
            m=int (input())
            EnterUserMove(m)
            DrawComputerMove()
        #VictoryFor(board, "O")
        
    if val==2 :
        if board[(0,1)]!="X" and board[(0,1)]!="O":
            board[(0,1)]="O"
            print (board[(0,1)])
            DisplayBoard(board)
            VictoryFor(board, "O")
            DrawComputerMove()
            
        else:
            print("In valid ! Enter Again : ")
            m=int (input())
            EnterUserMove(m)
            DrawComputerMove()
      #  VictoryFor(board, "O")
        

    if val==3 :
        if board[(0,2)]!="X" and board[(0,2)]!="O":
                board[(0,2)]="O"
                print (board[(0,2)])
                DisplayBoard(board)
                VictoryFor(board, "O")
                DrawComputerMove()
        else:
                print("In valid ! Enter Again : ")
                V=int(input())
                EnterUserMove(V)
                DrawComputerMove()
      #  VictoryFor(board, "O")

        
    if val==4 :
            if board[(1,0)]!="X" and board[(1,0)]!="O":
                board[(1,0)]="O"
                DisplayBoard(board)
                VictoryFor(board, "O")
                DrawComputerMove()
            else:
                print("In valid ! Enter Again : ")
                V=int(input())
                EnterUserMove(V)
                DrawComputerMove()
           # VictoryFor(board, "O")
            

    if val==5 :
            if board[(1,1)]!="X" and board[(1,1)]!="O":
                board[(1,1)]="O"
                print (board[(1,1)])
                DisplayBoard(board)
                VictoryFor(board, "O")
                DrawComputerMove()
            else:
                print("In valid ! Enter Again : ")
                V=int(input())
                EnterUserMove(V)
                DrawComputerMove()
            #VictoryFor(board, "O")

            
    if val==6 :
            if board[(1,2)]!="X" and board[(1,2)]!="O":
                board[(1,2)]="O"
                print (board[(1,2)])
                DisplayBoard(board)
                VictoryFor(board, "O")
                DrawComputerMove()
            else:
                print("In valid ! Enter Again : ")
                V=int(input())
                EnterUserMove(V)
                DrawComputerMove()
           # VictoryFor(board, "O")
            
    if val==7 :
            if board[(2,0)]!="X" and board[(2,0)]!="O":
                board[(2,0)]="O"
                print (board[(2,0)])
                DisplayBoard(board)
                VictoryFor(board, "O")
                DrawComputerMove()
            else:
                print("In valid ! Enter Again : ")
                V=int(input())
                EnterUserMove(V)
                DrawComputerMove()
          #  VictoryFor(board, "O")

            
    if val==8 :
            if board[(2,1)]!="X" and board[(2,1)]!="O":
                board[(2,1)]="O"
                print (board[(2,1)])
                DisplayBoard(board)
                VictoryFor(board, "O")
                DrawComputerMove()
            else:
                print("In valid ! Enter Again : ")
                V=int(input())
                EnterUserMove(V)
                DrawComputerMove()
            #VictoryFor(board, "O")

    if val==9 :
            if board[(2,2)]!="X" and board[(2,2)]!="O":
                board[(2,2)]="O"
                print (board[(2,2)])
                DisplayBoard(board)
                VictoryFor(board, "O")
                DrawComputerMove()
            else:
                print("In valid ! Enter Again : ")
                V=int(input())
                EnterUserMove(V)
                DrawComputerMove()
            #VictoryFor(board, "O")
    
    
    
    
    
    
    
    
    
    
def DrawComputerMove(): 
        Com_Turn=random.randint(1,9) 
        #print(Com_Turn)
        
        if Com_Turn==1:
            if board[(0,0)]!="X" and board[(0,0)]!="O":
                board[(0,0)]="X"
            else:
                print ("In Valid")
                DrawComputerMove()
#-----------------------------------------------------------------------------------------------            
        if Com_Turn==2 :
            if board[(0,1)]!="X" and board[(0,1)]!="O":
                board[(0,1)]="X"
                #print (board[(0,1)])
            else: 
                print ("In Valid")
                DrawComputerMove()
#-----------------------------------------------------------------------------------------------
        if Com_Turn==3:
            if board[(0,2)]!="X" and board[(0,2)]!="O":
                board[(0,2)]="X"
               # print (board[(0,2)])
            else:
                print ("In Valid")
                DrawComputerMove()
            #VictoryFor(board, "X")

        if Com_Turn==4:
            if board[(1,0)]!="X" and board[(1,0)]!="O":
                board[(1,0)]="X"
               # print (board[(1,0)])
            else:
                print ("In Valid")
                DrawComputerMove()
           # VictoryFor(board, "X")

        if Com_Turn==5 :
            if board[(1,1)]!="X" and board[(1,1)]!="O":
                board[(1,1)]="X"
               # print (board[(1,1)])
            else:
                print ("In Valid")
                DrawComputerMove()
           # VictoryFor(board, "X")
        
        if Com_Turn==6: 
            if board[(1,2)]!="X" and board[(1,2)]!="O":
                board[(1,2)]="X"
                #print (board[(1,2)])
            else:
                print ("In Valid")
                DrawComputerMove()
           # VictoryFor(board, "X")

        if Com_Turn==7 :
            if board[(2,0)]!="X" and board[(2,0)]!="O":
                board[(2,0)]="X"
               # print (board[(2,0)])
            else:
                print ("In Valid")
                DrawComputerMove()    
            #VictoryFor(board, "X")

        if Com_Turn==8 :
            if board[(2,1)]!="X" and board[(2,1)]!="O":
                board[(2,1)]="X"
                #print (board[(2,1)])
            else:
                print ("In Valid")
                DrawComputerMove()
           # VictoryFor(board, "X")

        if Com_Turn==9 :
            if board[(2,2)]!="X" and board[(2,2)]!="O":
                board[(2,2)]="X"
            else:
                print ("In Valid")
                DrawComputerMove()
                
            
        
        DisplayBoard(board)
        VictoryFor(board, "X")
        player=int(input("Enter Your Move : "))
        EnterUserMove(player)    
    
    
    
    
    
def VictoryFor(board, sign):
        if(board[(0,0)] == sign and board[(1,0)] == sign and board[(2,0)] == sign)or\
                (board[(0,1)] == sign and board[(1,1)] == sign and board[(2,1)] == sign)or\
                (board[(0,2)] == sign and board[(1,2)] == sign and board[(2,2)] == sign)or\
                (board[(0,0)] == sign and board[(1,1)] == sign and board[(2,2)] == sign)or\
                (board[(0,2)] == sign and board[(1,1)] == sign and board[(2,0)] == sign)or \
                (board[(0,0)] == sign and board[(0,1)] == sign and board[(0,2)] == sign)or\
                (board[(1,0)] == sign and board[(1,1)] == sign and board[(1,2)] == sign)or\
                (board[(2,0)] == sign and board[(2,1)] == sign and board[(2,2)] == sign):
                        print("Player " +sign.upper()+" win!")
                        sys.exit()   
        else:
            if  (board[(0,0)] == "X" or board[(0,0)] == "O") and \
                (board[(0,1)] == "X" or board[(0,1)]=="O")and\
                (board[(0,2)] == "X" or board[(0,2)] == "O" )and\
                (board[(1,0)] == "X" or board[(1,0)] == "O" )and\
                (board[(1,1)] == "X" or board[(1,1)] == "O" )and \
                (board[(1,2)] == "X" or board[(1,2)] == "O" )and \
                (board[(2,0)] == "X" or board[(2,0)] == "O" )and\
                (board[(2,1)] == "X" or board[(2,1)] == "O" )and\
                (board[(2,2)] == "X" or board[(2,2)] == "O" ):
                        print(" TIE !")
                        sys.exit() 
    
DrawComputerMove()
# Out:
# +-----+-----+-----+
# |     |     |     |
# | 1   |   2 |   3 |
# |     |     |     |
# +-----+-----+-----+
# |     |     |     |
# | 4   |   X |   6 |
# |     |     |     |
# +-----+-----+-----+
# |     |     |     |
# | 7   |   8 |   9 |
# |     |     |     |
# +-----+-----+-----+
# Enter Your Move : 1
# O
# +-----+-----+-----+
# |     |     |     |
# | O   |   2 |   3 |
# |     |     |     |
# +-----+-----+-----+
# |     |     |     |
# | 4   |   X |   6 |
# |     |     |     |
# +-----+-----+-----+
# |     |     |     |
# | 7   |   8 |   9 |
# |     |     |     |
# +-----+-----+-----+
# In Valid
# In Valid
# +-----+-----+-----+
# |     |     |     |
# | O   |   2 |   3 |
# |     |     |     |
# +-----+-----+-----+
# |     |     |     |
# | X   |   X |   6 |
# |     |     |     |
# +-----+-----+-----+
# |     |     |     |
# | 7   |   8 |   9 |
# |     |     |     |
# +-----+-----+-----+
# Enter Your Move : 2
# O
# +-----+-----+-----+
# |     |     |     |
# | O   |   O |   3 |
# ...
