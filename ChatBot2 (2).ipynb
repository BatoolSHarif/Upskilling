# %%
import re
import csv
import random
import requests
from pprint import pprint
import time
import matplotlib.image as m
import matplotlib.pyplot as plt
import sys
# sys.path.append(r'C:\\Users\\Batool\\Desktop\\Upskilling-Python\\chatbotProject\\Test1.ipynb')
# sys.path
# import Test1
def Temp(name,G):
    
    def weather_data(query):
        res=requests.get('http://api.openweathermap.org/data/2.5/weather?'+query+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric');
        return res.json();
    def print_weather(result,city):
        Temp=(city,result['main']['temp'])
        print(Temp)
        if Temp[1]>=25:
            print("Nice Wethear !");input("  Are going to have fun ?")
        else:
            S=[]
            print("writing ....\n") ; time.sleep(1) 
            print("Today is cold so "+name+" you should have a jacket wiht you");input("is it very cold ? \n")
            print("writing ....\n") ; time.sleep(1);input("What the color means to you ? \n");print("writing ....\n")
            time.sleep(1);S=input("Count the seven spectrum colors : \n")
            print("writing ....\n") ; time.sleep(1);print("To be sure they are (blue,red,green,indigo,orange,purple,yellow)")        
    city='Amman'
    print()
    try:
        query='q='+city;
        w_data=weather_data(query);
        print_weather(w_data, city)
        print()
    except:
        print('City name not found...')
    if G=="female":
        Female_Palette_Color(name)
        
#-----------------------------------------------------------------------------------------------------------                
        
def Game():
    c=0
    q1=input("cows eat milk ?[True/false]")
    if q1== "True" or q1== "true":
        print("oh No!")
    else:c=c+1;print("Yes,good job")
    q2=input("common name for this computer symbol (,) is Underscore[True/false]")
    if q2=="True" or q2=="true":
        print("oh No!")
    else:c=c+1;print("Yes,good job")
    q3=input("common name for this computer symbol (:) is colon[True/false]")
    if q3=="True"or q3=="true":c=c+1;print("Yes,good job")
    else:print("oh No!")
    q4=input("common name for this computer symbol ($) is dollar[True/false]")
    if q4== "True"or q4=="true":c=c+1;print("Yes,good job")
    else:print("oh No!")
    q5=input("science study of books is called bibilogy ?[True/false]")
    if q5== "True"or q5=="true":c=c+1;print("Yes,good job")
    else:print("oh No!")
    q6=input("Dakar the most northern [True/false]")
    if q6== "True"or q6=="true":c=c+1;print("Yes,good job")
    else:print("oh No!")
    q7=input("Santiago capital of chile[True/false]")
    if q7== "True"or q7=="true":c=c+1;print("Yes,good job")
    else:print("oh No!")
    q8=input("capital of Manila is Philippines [True/false]")
    if q8== "True"or q8=="true":c=c+1;print("Yes,good job")
    else:print("oh No!")
    q9=input("fish live in water [True/false]")
    if q9== "True"or q9=="true":c=c+1;print("Yes,good job")
    else:print("oh No!")
    q10=input("old is gold [True/false]")
    if q10== "True"or q10=="true":c=c+1;print("Yes,good job")
    else:print("oh No!")
    print("Score = ",c,"/10")
#-----------------------------------------------------------------------------------------------------------        
def Names():
    bad=["bad","not good"]
    In2=input()
    if In2=="how are you ?":
        print("writing ....") ; time.sleep(1)
        print("Iam fine thank you.","\nand you ?")
        In3=input()
        if In3 in bad:
            print("writing ....") ; time.sleep(1);In4=input("\nWhy ?");print("writing ....") ; time.sleep(1);print("No you desirve to be happy,so put a smile :) ");time.sleep(2)
    print("writing ....") ; time.sleep(1);In=input("What is your name ?");print("writing ....") ; time.sleep(1) 
    Gen= input("You are Male/Female ?")
    Temp(In,Gen)
#     if Gen=="female"or Gen=="Female" or Gen=="f" or Gen=="F":
#         Female_Palette_Color(In)
        
#         
#     elif Gen=="Male":
#         Male_Palette_Color()
#     else:
#         print("What do you mean ? Female or Male ?") ; Gen=input()
#     Occasion(In)      #Temp(In)
def Female_Palette_Color(I):
    
    with open("C:\\Users\\Batool\\Desktop\\Upskilling-Python\\chatbotProject\\Test.csv","r")as csvfile:
        reader=csv.reader(csvfile)
        header=next(reader)
        
        print("writing ....\n") ; time.sleep(2);A=input("How you choose your colors ?[Colors you like / no matter]\n")
        r=re.compile("\s*like\s*|\s*love\s*|\s*favorite\s*|\s*yes")
        if r.match(A)!=None:
            print("Nice")
        else:
            print("Nice")
        print("writing ....\n") ; time.sleep(2);A=input("based on what you make colthes color matching ?[scientific/random]")
        if A=="scientific":
            print("writing ....") ; time.sleep(2);X=input("How ? ")
            r=re.compile("color\s+palette")
            if r.match(X)!=None:
                print("Perfect")
        elif A=="random":
            print("writing ....") ; time.sleep(2);X=input("How ? ")
            print("writing ....") ; time.sleep(2);print("You should use color palette")
            
        print("writing ....\n") ; time.sleep(1);print(I+" Are you ready to be Awesome ! "+"\n so tell me "+I+" what's your baisc color today ?\n",header)
        Basic_Color=input()
#-----------------------------------------------------------------------------------------------------          
        Reg=re.compile("r|R\w*")
        R1=Reg.match(Basic_Color)
        if Basic_Color.lower()=="red" or R1!=None:
            print("writing ....\n") ; time.sleep(1);print("Nice color , you can make a color collection form these options\n ")
            for row in reader:
                time.sleep(1);print(row[0])
                img = m.imread('C:\\Users\\Batool\\Desktop\\Upskilling-Python\\chatbotProject\\R\\1.jpg') 
                plt.imshow(img) 
#-----------------------------------------------------------------------------------------------------  
        Reg=re.compile("g|G\w*")
        R1=Reg.match(Basic_Color)
        if Basic_Color.lower()=="green" or R1!=None:
            print("writing ....\n") ; time.sleep(1)
            print("Nice color , you can make a color collection form these options\n ")
            for row in reader:
                time.sleep(1);print(row[1])
            print("writing ....\n") ; time.sleep(1)
            img = m.imread('C:\\Users\\Batool\\Desktop\\Upskilling-Python\\chatbotProject\\G\\2.jpg') 
            plt.imshow(img) 
#-----------------------------------------------------------------------------------------------------  
        Reg=re.compile("b|B\w*")
        R1=Reg.match(Basic_Color)
        if Basic_Color.lower()=="blue"or R1!=None:
            print("writing ....\n") ; time.sleep(1); print("Nice color , you can make a color collection form these options\n ")
            for row in reader:
                time.sleep(1) ; print(row[2])
            print("writing ....\n") ; time.sleep(1)
            img = m.imread('C:\\Users\\Batool\\Desktop\\Upskilling-Python\\chatbotProject\\B\\3.jpg') 
            plt.imshow(img)
#-----------------------------------------------------------------------------------------------------            
        Reg=re.compile("y|Y\w*")
        R1=Reg.match(Basic_Color)
        if Basic_Color.lower()=="yellow" or R1!=None:
            print("writing ....\n") ; time.sleep(1);print("Nice color , you can make a color collection form these options\n ")
            for row in reader:
                time.sleep(1) ; print(row[3])
            print("writing ....\n") ; time.sleep(1)
            img = m.imread('C:\\Users\\Batool\\Desktop\\Upskilling-Python\\chatbotProject\\Y\\6.jpg') 
            plt.imshow(img)
#-----------------------------------------------------------------------------------------------------              
        Reg=re.compile("p|P\w*")
        R1=Reg.match(Basic_Color)
        if Basic_Color.lower()=="purple"or R1!=None:
            print("writing ....\n") ; time.sleep(1);print("Nice color , you can make a color collection form these options\n ")
            for row in reader:
                time.sleep(1) ; print(row[4])
            print("writing ....\n") ; time.sleep(1)
            img = m.imread('C:\\Users\\Batool\\Desktop\\Upskilling-Python\\chatbotProject\\P\\4.jpg') 
            plt.imshow(img)
#-----------------------------------------------------------------------------------------------------              
        Reg=re.compile("o|O\w*")
        R1=Reg.match(Basic_Color)    
        if Basic_Color.lower()=="orange"or R1!=None:
            print("writing ....\n") ; time.sleep(1);print("Nice color , you can make a color collection form these options\n ")
            for row in reader:
                time.sleep(1) ; print(row[5])
            print("writing ....\n") ; time.sleep(1)
            img = m.imread('C:\\Users\\Batool\\Desktop\\Upskilling-Python\\chatbotProject\\O\\4.jpg') 
            plt.imshow(img) 
#-----------------------------------------------------------------------------------------------------          
        Reg=re.compile("i|I\w*")
        R1=Reg.match(Basic_Color)
        if Basic_Color.lower()=="indigo"or R1!=None:
            print("writing ....\n") ; time.sleep(1);print("Nice color , you can make a color collection form these options\n ")
            for row in reader:
                time.sleep(1) ; print(row[6])
            img = m.imread('C:\\Users\\Batool\\Desktop\\Upskilling-Python\\chatbotProject\\I\\4.jpg') 
            plt.imshow(img)      
        print("writing ....\n") ; time.sleep(2);A=input("Which option you chooes ?\n");print("Nice one\n")
        print("writing ....\n") ; time.sleep(2);A=input("The options was enough ?\n")
        if A=="no"or A=="No" or A=="NO":print("for more press the link : https://stock.adobe.com")
        print("writing ....\n") ; time.sleep(2);A=input("Tell me what is a color palette ?\n");print("Color palette refers to particular combination of colors\n")
        print("writing ....\n") ; time.sleep(2);B=input("are going to use color palette ?\n")
        if B=="yes":
            print("Thats perfect")
        elif B=="no":
            print("Try to use it ,It will help you alot")
        print("writing ....\n") ; time.sleep(2);A=input("can you tell me anything about colors ?")
        Occasion(I)
#-----------------------------------------------------------------------------------------------------              
def Fav_Color():
    print("writing ....\n");time.sleep(1); print("Welcome to color personal analysis \n");print("writing ....\n");time.sleep(1);Color=input("What is youre fav color ? \n");print("writing ....");time.sleep(1)
    F=input("Do you have more than one favorite color ?[yes/no] \n")
    if F=="yes":print("writing ....\n");time.sleep(1);Color=input("Give me one you like ? \n")
    with open("C:\\Users\\Batool\\Desktop\\Upskilling-Python\\chatbotProject\\ChatBotFiles\\PerAnalysis.csv",'r')as csvfile:
        reader=csv.reader(csvfile)
        for row in reader:
            if (Color.lower()!="red" and Color.lower()!="yellow" and Color.lower()!="green" and Color.lower()!="orange" and Color.lower()!="blue" and Color.lower()!="indigo" and Color.lower()!="purple")==True:
                print("writing ....");time.sleep(1);print("Sorry!")
                Color=input("What is youre fav color ? \n")
            else:
                if Color.lower()=="green":
                    print("writing ....");time.sleep(2);print(row[4])
                elif Color.lower()=="red" :
                    print("writing ....");time.sleep(2);print(row[0])
                elif Color.lower()=="yellow":
                    print("writing ....");time.sleep(2);print(row[3])
                elif Color.lower()=="blue":
                    print("writing ....");time.sleep(2);print(row[5])
                elif Color.lower()=="orange":
                    print("writing ....");time.sleep(2);print(row[2])
                elif Color.lower() =="purple":
                    print("writing ....");time.sleep(2);print(row[1])
                elif Color.lower()=="idigo":
                    print("writing ....");time.sleep(2);print(row[6]) 
        print("writing ....\n");time.sleep(1);X=input("have your favorite color changed ? \n")
        print("writing ....\n");time.sleep(1);print("You know changing favorite color means you should\n'try to identify the circumstances surrounding your life at that time' \n");time.sleep(2)
        print("writing ....\n");time.sleep(2);A=input(" 'Circumstances' is it clear to you ? [yes/no] \n")
        if A=='yes':print("writing ....\n");time.sleep(1);input("Tell what its means ? \n")
        else:print("writing ....\n");time.sleep(1);print("Circumstances means :situation  \n");time.sleep(2)
        print("writing ....\n");time.sleep(1);
        input("Tell me what was your favorite before it changed 'if its changed' ? \n");print("writing ....\n");time.sleep(1);input("What are the most words you like ?[creative,unconditional,strong,innocence]")
        with open("C:\\Users\\Batool\\Desktop\\Upskilling-Python\\chatbotProject\\ChatBotFiles\\Pos-NegWords.csv",'r')as csvfile:
            reader2=csv.reader(csvfile)
            print("writing ....\n");time.sleep(1);print("You know people whose favorite color is :"+Color+" have positive and negative traits:\n");time.sleep(2)
            for raw in reader2:
                if Color=="purple":
                    print(raw[0],end="\n")
                elif Color=="red":
                    print(raw[1],end="\n")
                elif Color=="orange":
                    print(raw[2],end="\n")
                elif Color=="yellow":
                    print(raw[3],end="\n")
                elif Color=="green":
                    print(raw[4],end="\n")
                elif Color=="blue":
                    print(raw[5],end="\n")
                elif Color=="indigo":
                    print(raw[6],end="\n")  
        
#-----------------------------------------------------------------------------------------------------                                  
def Occasion(In):
        li=["party","dinner","work",'sport']
        Occ=input ("what is your occasion ?\n[party,dinner,work,sport]\n")
    
        if Occ==li[0]:
            Oc2=input("is it indoor or outdoor ?");print("writing ...") ; time.sleep(1);print("Have fun\n");Oc3=input("you prefer to wear in formal way in general ? \n");input();print("writing ....") ; time.sleep(1);print("I prefer casual")
            Oc4=input("do you prefer this kind of occasion ? or you Prefer different type? ");print("writing ....") ; time.sleep(1)
            Oc1=input("Nice Enjoy "+In+" you will wear dress or skirt ? \n")
            input("It think is better to wear a dress,what do you think ?\n")
            print("writing ....");time.sleep(1); print("Cool")
            print("writing ....");time.sleep(1); Oc6=input("every thing is ok untill now ? [yes/No] \n")
            if Oc6=="yes":
                print("writing ....");time.sleep(1);print("lets play and have fun\n")
                Game()
            elif Oc6=="no":
                print("writing ....");time.sleep(1);print("lets play and have fun\n")
                Game()
            
        if Occ==li[1]:
            Oc1=input("is it indoor or outdoor ?\n");print("writing ....\n") ; time.sleep(1);print("Have fun\n");Oc3=input("you prefer to wear in formal way in general ? \n");input();print("writing ....") ; time.sleep(1);print("I prefer casual \n")
            Oc4=input("do prefer this kind of occasion ? or you Prefer different type ? \n");print("writing ....\n") ; time.sleep(1)
            Oc12=input("Tts dinner time "+In+"a business or family dinner ? \n")
            Oc2=input("so today you will wear dress or casual ? \n")
            input("It think is better to wear formal in business dinner,what do you think ? \n")
            print("writing ....\n");time.sleep(1); print("Cool\n")
            print("writing ....\n");time.sleep(1); Oc6=input("every thing is ok untill now ? [yes/No] \n")
            if Oc6=="yes":
                print("writing ....");time.sleep(1);print("lets play and have fun\n")
                Game()
            elif Oc6=="no":
                print("writing ....");time.sleep(1);print("lets play and have fun\n")
                Game()
        if Occ==li[2]:
            Oc1=input("is it office or outoffice ?");print("writing ....\n") ; time.sleep(1);print("Have fun");Oc3=input("you prefer to wear in formal way in general ? ");input();print("writing ....\n") ; time.sleep(1);print("I prefer casual")
            Oc4=input("do prefer this kind of occasion ? or you Prefer different type? ");print("writing ....\n") ; time.sleep(1)
            Oc12=input("Its work time "+In+" casual or Jeans? \n")
            input("Any of them is good,what do you think ? \n")
            print("writing ....");time.sleep(1); print("Cool")
            print("writing ....");time.sleep(1); Oc6=input("every thing is ok untill now ?[yes/No] \n")
            if Oc6=="yes":
                print("writing ....");time.sleep(1);print("lets play and have fun\n")
                Game()
            elif Oc6=="no":
                print("writing ....");time.sleep(1);print("lets play and have fun\n")
                Game()
        if Occ==li[3]:
            Oc1=input("is it office or outoffice ?");print("writing ....\n") ; time.sleep(1);Oc4=input("do prefer this kind of occasion ? or you Prefer different type ? \n");print("writing ....\n") ; time.sleep(1)
            Oc12=input("123 Healthy life yes ! "+In+" so adidas ? \n")
            input("The most Important is comfortability,Right ? \n")
            print("writing ....\n") ; time.sleep(1)
            input("what you are going to wear ?\n")
            print("writing ....");time.sleep(1); print("Cool");Oc3=input("you prefer to wear in formal way in general? \n")
            print("writing ....");time.sleep(1); Oc6=input("every thing is ok untill now ? [yes/No]\n")
            if Oc6=="yes":
                print("writing ....");time.sleep(1);print("lets play and have fun\n")
                Game()
            elif Oc6=="no":
                print("writing ....");time.sleep(1);print("lets play and have fun\n")
                Game()
        Fav_Color()
        
GREETING_KEYWORDS = ("hello", "hi", "greetings", "sup", "what's up",)
GREETING_RESPONSES = ["hello", "hey", "hi", "hey you get my snap?"]
def check_for_greeting(sentence):
    """If any of the words in the user's input was a greeting, return a greeting response"""
    for word in sentence:
        if word.lower() in GREETING_KEYWORDS:
            print("writing ....") ; time.sleep(1)
            print (random.choice(GREETING_RESPONSES)) ; Names()
    
# def Qustions ():
#     with open("C:\\Users\\Batool\\Desktop\\Upskilling-Python\\chatbotProject\\Test.csv","r")as csvfile:
#         reader=csv.reader(csvfile)
 
sent=input()
st=[]
st.append(sent)
check_for_greeting(st)
# Out:
# hi
# writing ....
# hey
# how are you ?
# writing ....
# Iam fine thank you.
# and you ?
# good
# writing ....
# What is your name ?batool
# writing ....
# You are Male/Female ?female
#
# ('Amman', 15)
# writing ....
#
# Today is cold so batool you should have a jacket wiht you
# is it very cold ?
# yes
# writing ....
#
# What the color means to you ?
# sdjg
# writing ....
#
# Count the seven spectrum colors :
# vi
# writing ....
#
# To be sure they are (blue,red,green,indigo,orange,purple,yellow)
#
# writing ....
#
# How you choose your colors ?[Colors you like / no matter]
# like
# Nice
# writing ....
#
# based on what you make colthes color matching ?[scientific/random]random
# writing ....
# How ? chj
# writing ....
# You should use color palette
# writing ....
#
# batool Are you ready to be Awesome !
#  so tell me batool what's your baisc color today ?
#  ['red', 'green', 'blue', 'yellow', 'purple', 'orange', 'indigo']
# red
# writing ....
#
# ...
